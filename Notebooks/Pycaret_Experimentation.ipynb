# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pycaret.classification import *
# import ClassificationExperiment
from pycaret.classification import ClassificationExperiment

# %%
# and init the class
exp = ClassificationExperiment()

# %%
df = pd.read_csv('../Data/new_data.csv')
df.head()
# Out:
#    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0   50       2     168      62    110     80            1     1      0     0
# 1   55       1     156      85    140     90            3     1      0     0
# 2   51       1     165      64    130     70            3     1      0     0
# 3   48       2     169      82    150    100            1     1      0     0
# 4   47       1     156      56    100     60            1     1      0     0
#
#    active  cardio  BMI
# 0       1       0   21
# 1       1       1   34
# 2       0       1   23
# 3       1       1   28
# 4       0       0   23

# %%
clf_exp = setup(data = df, target = 'cardio')
# Out:
# <style type="text/css">
# #T_9f117_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9f117">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f117_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9f117_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f117_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f117_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9f117_row0_col1" class="data row0 col1" >1134</td>
#     </tr>
#     <tr>
#       <th id="T_9f117_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9f117_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9f117_row1_col1" class="data row1 col1" >cardio</td>
#     </tr>
#     <tr>
#       <th id="T_9f117_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models(sort = 'precision')
# Out:
# <style type="text/css">
# #T_e4202 th {
#   text-align: left;
# }
# ...

# %%
# init setup on exp
exp.setup(df, target = 'cardio', session_id = 123)
# Out:
# <style type="text/css">
# #T_b90ec_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b90ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b90ec_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b90ec_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b90ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b90ec_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b90ec_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b90ec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b90ec_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b90ec_row1_col1" class="data row1 col1" >cardio</td>
#     </tr>
#     <tr>
#       <th id="T_b90ec_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# compare models using OOP
exp.compare_models()
# Out:
# <style type="text/css">
# #T_cac37 th {
#   text-align: left;
# }
# ...

# %%
# plot confusion matrix
plot_model(best_model, plot = 'confusion_matrix')

# %%
# plot AUC
plot_model(best_model, plot = 'auc')

# %%
# plot feature importance
plot_model(best_model, plot = 'feature')

# %% [markdown]
# ### Create Model

# %%
# check all the available models
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
# train Ada Boost Classifier with default fold=10
ada = create_model('ada')
# Out:
# <style type="text/css">
# #T_d48d9_row10_col0, #T_d48d9_row10_col1, #T_d48d9_row10_col2, #T_d48d9_row10_col3, #T_d48d9_row10_col4, #T_d48d9_row10_col5, #T_d48d9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d48d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d48d9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d48d9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d48d9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d48d9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d48d9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d48d9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d48d9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# train Light Gradient Boosting Machine with default fold=10
lightgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_ec43f_row10_col0, #T_ec43f_row10_col1, #T_ec43f_row10_col2, #T_ec43f_row10_col3, #T_ec43f_row10_col4, #T_ec43f_row10_col5, #T_ec43f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ec43f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec43f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ec43f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ec43f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ec43f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ec43f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ec43f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ec43f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# train Gradient Boosting Classifier with default fold=10
gbc = create_model('gbc')
# Out:
# <style type="text/css">
# #T_caede_row10_col0, #T_caede_row10_col1, #T_caede_row10_col2, #T_caede_row10_col3, #T_caede_row10_col4, #T_caede_row10_col5, #T_caede_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_caede">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_caede_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_caede_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_caede_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_caede_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_caede_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_caede_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_caede_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# train logistic regression with default fold=10
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_1a801_row10_col0, #T_1a801_row10_col1, #T_1a801_row10_col2, #T_1a801_row10_col3, #T_1a801_row10_col4, #T_1a801_row10_col5, #T_1a801_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1a801">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a801_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1a801_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1a801_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1a801_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1a801_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1a801_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1a801_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...
